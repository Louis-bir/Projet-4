# %% [markdown]
# # PROJET : Anticiper les besoins en consommation électrique de bâtiments

# %% [markdown]
# **Autor** : Louis BIRENHOLZ
# **Date** : 12/03/2020
# **Durée totale (3 notebooks)** : 100 heures
# **Vidéo du projet** : https://www.youtube.com/watch?v=GRcUu2_YbFE&feature=emb_title

# %% [markdown]
# Pour ce projet, nous nous intéressons aux objectifs de la ville de **Seattle** : **devenir une ville neutre en émissions de carbone en 2050**. On s’intéresse de près aux émissions des bâtiments non destinés à l’habitation.
#
# On souhaite prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments pour lesquels elles n’ont pas encore été mesurées. Ces mesures sont chères et complexes à réaliser.

# %% [markdown]
# ## Partie 1 : Cleaning & Preprocessing

# %% [markdown]
# Ce 1er notebook réalise un **cleaning des données**, du **feature engineering** et la création d'un **unique dataframe** pour la suite.

# %% [markdown]
# ## Librairies

# %%
# Classic lib.
import pandas as pd
import numpy as np

# Viz lib.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from ast import literal_eval

# %% [markdown]
# ## Settings

# %%
# Style.
plt.style.use('ggplot')
sns.set_style("darkgrid")

# Option.
pd.options.display.max_columns = 100

# %% [markdown]
# ## Data

# %%
# Données de 2015.
data2015 = pd.read_csv("2015-building-energy-benchmarking.csv", sep=',')

# Données de 2016.
data2016 = pd.read_csv("2016-building-energy-benchmarking.csv", sep=',')

# %%
# Dimensions.
print(data2015.shape)
print(data2016.shape)
# Out:
# (3340, 47)
# (3376, 46)

# %%
# Check des lignes dupliquées.
data2015.drop_duplicates(inplace = True)
data2016.drop_duplicates(inplace = True)

print(data2015.shape)
print(data2016.shape)
# Out:
# (3340, 47)
# (3376, 46)

# %% [markdown]
# ## Quick check 2015 & 2016

# %%
data2015.head(3)
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
#
#            PropertyName TaxParcelIdentificationNumber  CouncilDistrictCode  \
# 0  MAYFLOWER PARK HOTEL                     659000030                    7
# 1       PARAMOUNT HOTEL                     659000220                    7
# 2          WESTIN HOTEL                     659000475                    7
#
#   Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 0     DOWNTOWN       1927                  1            12.0
# 1     DOWNTOWN       1996                  1            11.0
# 2     DOWNTOWN       1969                  1            41.0
#
#    PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 0             88434                   0                   88434
# 1            103566               15064                   88502
# 2            961990                   0                  961990
#
#        ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 0                          Hotel                  Hotel
# 1     Hotel, Parking, Restaurant                  Hotel
# 2  Hotel, Parking, Swimming Pool                  Hotel
#
#    LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0                    88434.0                          NaN
# 1                    83880.0                      Parking
# 2                   757243.0                      Parking
#
#    SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                              NaN                         NaN
# 1                          15064.0                  Restaurant
# 2                         100000.0               Swimming Pool
#
#    ThirdLargestPropertyUseTypeGFA YearsENERGYSTARCertified  ENERGYSTARScore  \
# 0                             NaN                      NaN             65.0
# 1                          4622.0                      NaN             51.0
# 2                             0.0                      NaN             18.0
#
#    SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  \
# 0              78.9                80.3               173.5
# 1              94.4                99.0               191.3
# 2              96.6                99.7               242.7
#
#    SourceEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# 0                 175.1            6981428.0              7097539.0
# 1                 195.2            8354235.0              8765788.0
# 2                 246.5           73130656.0             75506272.0
#
#    SteamUse(kBtu)  Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 0       2023032.0         1080307.0          3686160.0             12724.0
# 1             0.0         1144563.0          3905411.0             44490.0
# 2      19660404.0        14583930.0         49762435.0             37099.0
#
#    NaturalGas(kBtu)  OtherFuelUse(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 0         1272388.0                 0.0                        249.43
# 1         4448985.0                 0.0                        263.51
# 2         3709900.0                 0.0                       2061.48
#
#    GHGEmissionsIntensity(kgCO2e/ft2) DefaultData ComplianceStatus  \
# 0                               2.64          No        Compliant
# 1                               2.38          No        Compliant
# 2                               1.92         Yes        Compliant
#
#    City Council Districts  SPD Beats  Zip Codes     Latitude      Longitude
# 0                     NaN       31.0      18081  47.61219025  -122.33799744
# 1                     NaN       31.0      18081  47.61310583  -122.33335756
# 2                     NaN       31.0      18081  47.61334897  -122.33769944

# %%
data2016.head(3)
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
#
#               PropertyName TaxParcelIdentificationNumber  CouncilDistrictCode  \
# 0     Mayflower park hotel                    0659000030                    7
# 1          Paramount Hotel                    0659000220                    7
# 2  5673-The Westin Seattle                    0659000475                    7
#
#   Neighborhood  Latitude  Longitude  YearBuilt  NumberofBuildings  \
# 0     DOWNTOWN  47.61220 -122.33799       1927                1.0
# 1     DOWNTOWN  47.61317 -122.33393       1996                1.0
# 2     DOWNTOWN  47.61393 -122.33810       1969                1.0
#
#    NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0              12             88434                   0
# 1              11            103566               15064
# 2              41            956110              196718
#
#    PropertyGFABuilding(s)   ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 0                   88434                       Hotel                  Hotel
# 1                   88502  Hotel, Parking, Restaurant                  Hotel
# 2                  759392                       Hotel                  Hotel
#
#    LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 0                    88434.0                          NaN
# 1                    83880.0                      Parking
# 2                   756493.0                          NaN
#
#    SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                              NaN                         NaN
# 1                          15064.0                  Restaurant
# 2                              NaN                         NaN
#
#    ThirdLargestPropertyUseTypeGFA YearsENERGYSTARCertified  ENERGYSTARScore  \
# 0                             NaN                      NaN             60.0
# 1                          4622.0                      NaN             61.0
# 2                             NaN                      NaN             43.0
#
#    SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  \
# 0         81.699997           84.300003          182.500000
# 1         94.800003           97.900002          176.100006
# 2         96.000000           97.699997          241.899994
#
#    SourceEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# 0            189.000000            7226362.5              7456910.0
# 1            179.399994            8387933.0              8664479.0
# 2            244.100006           72587024.0             73937112.0
#
#    SteamUse(kBtu)  Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 0       2003882.0      1.156514e+06          3946027.0         12764.52930
# 1             0.0      9.504252e+05          3242851.0         51450.81641
# 2      21566554.0      1.451544e+07         49526664.0         14938.00000
#
#    NaturalGas(kBtu)  DefaultData ComplianceStatus  TotalGHGEmissions  \
# 0         1276453.0        False        Compliant             249.98
# 1         5145082.0        False        Compliant             295.86
# 2         1493800.0        False        Compliant            2089.28
#
#    GHGEmissionsIntensity
# 0                   2.83
# 1                   2.86
# 2                   2.19

# %% [markdown]
# ## Cleaning

# %%
# A t-on les mêmes colonnes dans les 2 dataframes ?

Col_absentes_A=[]
Col_absentes_B=[]

for i,j in zip(data2015.columns,data2016.columns):
    if i not in data2016.columns:
        Col_absentes_A.append(i)
    if j not in data2015.columns:
        Col_absentes_B.append(j)  
        
print(" Les colonnes présentent dans 2015 mais pas dans 2016 sont :",Col_absentes_A,".")
print("***************************")
print(print(" Les colonnes présentent dans 2016 mais pas dans 2015 sont :",Col_absentes_B,"."))
# Out:
#  Les colonnes présentent dans 2015 mais pas dans 2016 sont : ['Location', 'OtherFuelUse(kBtu)', 'GHGEmissions(MetricTonsCO2e)', 'GHGEmissionsIntensity(kgCO2e/ft2)', 'Comment', '2010 Census Tracts', 'Seattle Police Department Micro Community Policing Plan Areas', 'City Council Districts', 'SPD Beats'] .
# ***************************
#  Les colonnes présentent dans 2016 mais pas dans 2015 sont : ['Address', 'City', 'State', 'ZipCode', 'Latitude', 'Longitude', 'Comments', 'TotalGHGEmissions', 'GHGEmissionsIntensity'] .
# None

# %% [markdown]
# ## Check des NaN

# %%
# 2015.
df_2015_NaN = pd.DataFrame(((data2015.notnull().sum().sort_values(ascending=False))/np.shape(data2015)[0])*100)
df_2015_NaN.columns = ['% de données dispo']
df_2015_NaN
# Out:
#                                                     % de données dispo
# Zip Codes                                                   100.000000
# PropertyGFABuilding(s)                                      100.000000
# DataYear                                                    100.000000
# BuildingType                                                100.000000
# PrimaryPropertyType                                         100.000000
# PropertyName                                                100.000000
# Location                                                    100.000000
# CouncilDistrictCode                                         100.000000
# Neighborhood                                                100.000000
# YearBuilt                                                   100.000000
# NumberofBuildings                                           100.000000
# PropertyGFATotal                                            100.000000
# PropertyGFAParking                                          100.000000
# OSEBuildingID                                               100.000000
# ComplianceStatus                                            100.000000
# DefaultData                                                  99.970060
# Seattle Police Department Micro Community Polic...           99.940120
# TaxParcelIdentificationNumber                                99.940120
# SPD Beats                                                    99.940120
# NumberofFloors                                               99.760479
# NaturalGas(kBtu)                                             99.700599
# NaturalGas(therms)                                           99.700599
# Electricity(kWh)                                             99.700599
# GHGEmissions(MetricTonsCO2e)                                 99.700599
# GHGEmissionsIntensity(kgCO2e/ft2)                            99.700599
# Electricity(kBtu)                                            99.700599
# SiteEUI(kBtu/sf)                                             99.700599
# SiteEUIWN(kBtu/sf)                                           99.700599
# SourceEUI(kBtu/sf)                                           99.700599
# SourceEUIWN(kBtu/sf)                                         99.700599
# SiteEnergyUse(kBtu)                                          99.700599
# SiteEnergyUseWN(kBtu)                                        99.700599
# SteamUse(kBtu)                                               99.700599
# OtherFuelUse(kBtu)                                           99.700599
# ListOfAllPropertyUseTypes                                    96.197605
# LargestPropertyUseType                                       95.928144
# LargestPropertyUseTypeGFA                                    95.928144
# ENERGYSTARScore                                              76.646707
# SecondLargestPropertyUseType                                 46.676647
# SecondLargestPropertyUseTypeGFA                              46.676647
# ThirdLargestPropertyUseType                                  16.766467
# ThirdLargestPropertyUseTypeGFA                               16.766467
# 2010 Census Tracts                                            6.706587
# City Council Districts                                        6.377246
# YearsENERGYSTARCertified                                      3.293413
# Outlier                                                       2.514970
# Comment                                                       0.389222

# %%
# 2016.
df_2016_NaN = pd.DataFrame(((data2016.notnull().sum().sort_values(ascending=False))/np.shape(data2016)[0])*100)
df_2016_NaN.columns = ['% de données dispo']
df_2016_NaN
# Out:
#                                  % de données dispo
# OSEBuildingID                            100.000000
# PropertyGFABuilding(s)                   100.000000
# PropertyGFATotal                         100.000000
# NumberofFloors                           100.000000
# YearBuilt                                100.000000
# Longitude                                100.000000
# Latitude                                 100.000000
# Neighborhood                             100.000000
# CouncilDistrictCode                      100.000000
# TaxParcelIdentificationNumber            100.000000
# PropertyGFAParking                       100.000000
# State                                    100.000000
# City                                     100.000000
# Address                                  100.000000
# PropertyName                             100.000000
# PrimaryPropertyType                      100.000000
# DefaultData                              100.000000
# BuildingType                             100.000000
# ComplianceStatus                         100.000000
# DataYear                                 100.000000
# SiteEnergyUse(kBtu)                       99.851896
# SiteEnergyUseWN(kBtu)                     99.822275
# SiteEUIWN(kBtu/sf)                        99.822275
# SiteEUI(kBtu/sf)                          99.792654
# NumberofBuildings                         99.763033
# GHGEmissionsIntensity                     99.733412
# ListOfAllPropertyUseTypes                 99.733412
# SourceEUI(kBtu/sf)                        99.733412
# NaturalGas(kBtu)                          99.733412
# NaturalGas(therms)                        99.733412
# Electricity(kBtu)                         99.733412
# Electricity(kWh)                          99.733412
# SteamUse(kBtu)                            99.733412
# SourceEUIWN(kBtu/sf)                      99.733412
# TotalGHGEmissions                         99.733412
# ZipCode                                   99.526066
# LargestPropertyUseType                    99.407583
# LargestPropertyUseTypeGFA                 99.407583
# ENERGYSTARScore                           75.029621
# SecondLargestPropertyUseTypeGFA           49.733412
# SecondLargestPropertyUseType              49.733412
# ThirdLargestPropertyUseTypeGFA            17.654028
# ThirdLargestPropertyUseType               17.654028
# YearsENERGYSTARCertified                   3.524882
# Outlier                                    0.947867
# Comments                                   0.000000

# %% [markdown]
# ## Check des outliers

# %% [markdown]
# Exploration de la colonne nommée **outlier**

# %%
data2015['Outlier'] = data2015['Outlier'].fillna(0)
data2016['Outlier'] = data2016['Outlier'].fillna(0)

mask1 = (data2015['Outlier'] != 0)
mask2 = (data2015['Outlier'] == 0)
mask3 = (data2016['Outlier'] == 0)

A = data2015[mask1]['GHGEmissions(MetricTonsCO2e)'].dropna()
B = data2015[mask2]['GHGEmissions(MetricTonsCO2e)'].dropna()

# %%
# Delete outliers.

data2015 = data2015[mask2]
data2016 = data2016[mask3]

# On retire la colonne Outlier.
del data2015['Outlier']
del data2016['Outlier']

# %%
print(type(data2015["Location"][0])) # Objet de type str.
data2015["Location"] = data2015["Location"].apply(literal_eval) # On change avec .apply(literal_eval) un string en dictionnaire.
print(type(data2015["Location"][0])) # Objet de type dictionnaire .
# Out:
# <class 'str'>
# <class 'dict'>

# %%
data2015["Latitude"] = data2015["Location"].apply(lambda x : x["latitude"]) # On applique la clé "latitude" à l'ensemble de la colonne "location".
data2015["Longitude"] = data2015["Location"].apply(lambda x : x["longitude"])

# %%
# Destruction de colonnes inutiles pour la concaténation de 2015 et 2016.

data2015.drop(['Location','Comment','2010 Census Tracts',
               'Seattle Police Department Micro Community Policing Plan Areas'], axis = 1, inplace = True)
data2016.drop(['Address', 'City', 'State', 'ZipCode', 'Comments'],axis = 1, inplace = True)

# %%
# On retient seulement les bâtiments non résidentiels pour l'étude.

print(data2015['BuildingType'].unique())
print(data2016['BuildingType'].unique())

NonResidential_building = ['NonResidential','Nonresidential COS','Campus','Nonresidential WA']
# Out:
# ['NonResidential' 'Nonresidential COS' 'Multifamily MR (5-9)'
#  'SPS-District K-12' 'Multifamily LR (1-4)' 'Campus'
#  'Multifamily HR (10+)']
# ['NonResidential' 'Nonresidential COS' 'Multifamily MR (5-9)'
#  'SPS-District K-12' 'Campus' 'Multifamily LR (1-4)'
#  'Multifamily HR (10+)' 'Nonresidential WA']

# %%
# On ne prend que les bâtiments non residentiels.

mask1 = (data2015['BuildingType'].isin(NonResidential_building))
mask2 = (data2016['BuildingType'].isin(NonResidential_building))

df2015 = data2015[mask1]
df2016 = data2016[mask2]

# %%
print(df2015['BuildingType'].unique())
print(df2016['BuildingType'].unique())
# Out:
# ['NonResidential' 'Nonresidential COS' 'Campus']
# ['NonResidential' 'Nonresidential COS' 'Campus' 'Nonresidential WA']

# %%
# Concaténation des 2 dataframes 2015 et 2016 pour former data_tot.

df_tot = pd.concat([df2015,df2016],sort=False)
df_tot.head()
# Out:
#    OSEBuildingID  DataYear        BuildingType PrimaryPropertyType  \
# 0              1      2015      NonResidential               Hotel
# 1              2      2015      NonResidential               Hotel
# 2              3      2015      NonResidential               Hotel
# 4              8      2015      NonResidential               Hotel
# 5              9      2015  Nonresidential COS               Other
#
#                      PropertyName TaxParcelIdentificationNumber  \
# 0            MAYFLOWER PARK HOTEL                     659000030
# 1                 PARAMOUNT HOTEL                     659000220
# 2                    WESTIN HOTEL                     659000475
# 4           WARWICK SEATTLE HOTEL                     659000970
# 5  WEST PRECINCT (SEATTLE POLICE)                     660000560
#
#    CouncilDistrictCode Neighborhood  YearBuilt  NumberofBuildings  \
# 0                    7     DOWNTOWN       1927                1.0
# 1                    7     DOWNTOWN       1996                1.0
# 2                    7     DOWNTOWN       1969                1.0
# 4                    7     DOWNTOWN       1980                1.0
# 5                    7     DOWNTOWN       1999                1.0
#
#    NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0            12.0             88434                   0
# 1            11.0            103566               15064
# 2            41.0            961990                   0
# 4            18.0            119890               12460
# 5             2.0             97288               37198
#
#    PropertyGFABuilding(s)      ListOfAllPropertyUseTypes  \
# 0                   88434                          Hotel
# 1                   88502     Hotel, Parking, Restaurant
# 2                  961990  Hotel, Parking, Swimming Pool
# 4                  107430  Hotel, Parking, Swimming Pool
# 5                   60090                 Police Station
#
#   LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 0                  Hotel                    88434.0
# 1                  Hotel                    83880.0
# 2                  Hotel                   757243.0
# 4                  Hotel                   123445.0
# 5         Police Station                    88830.0
#
#   SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 0                          NaN                              NaN
# 1                      Parking                          15064.0
# 2                      Parking                         100000.0
# 4                      Parking                          68009.0
# 5                          NaN                              NaN
#
#   ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 0                         NaN                             NaN
# 1                  Restaurant                          4622.0
# 2               Swimming Pool                             0.0
# 4               Swimming Pool                             0.0
# 5                         NaN                             NaN
#
#   YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                      NaN             65.0              78.9
# 1                      NaN             51.0              94.4
# 2                      NaN             18.0              96.6
# 4                      NaN             67.0             120.1
# 5                      NaN              NaN             135.7
#
#    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 0                80.3               173.5                 175.1
# 1                99.0               191.3                 195.2
# 2                99.7               242.7                 246.5
# 4               122.1               228.8                 227.1
# 5               146.9               313.5                 321.6
#
#    SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 0            6981428.0              7097539.0       2023032.0
# 1            8354235.0              8765788.0             0.0
# 2           73130656.0             75506272.0      19660404.0
# 4           14829099.0             15078243.0             0.0
# 5           12051984.0             13045258.0             0.0
#
#    Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  \
# 0         1080307.0          3686160.0             12724.0         1272388.0
# 1         1144563.0          3905411.0             44490.0         4448985.0
# 2        14583930.0         49762435.0             37099.0         3709900.0
# 4         1777841.0          6066245.0             87631.0         8763105.0
# 5         2130921.0          7271004.0             47813.0         4781283.0
#
#    OtherFuelUse(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 0                 0.0                        249.43
# 1                 0.0                        263.51
# 2                 0.0                       2061.48
# 4                 0.0                        507.70
# 5                 0.0                        304.62
#
#    GHGEmissionsIntensity(kgCO2e/ft2) DefaultData ComplianceStatus  \
# 0                               2.64          No        Compliant
# 1                               2.38          No        Compliant
# 2                               1.92         Yes        Compliant
# 4                               4.02          No        Compliant
# 5                               2.81          No        Compliant
#
#    City Council Districts  SPD Beats  Zip Codes     Latitude      Longitude  \
# 0                     NaN       31.0    18081.0  47.61219025  -122.33799744
# 1                     NaN       31.0    18081.0  47.61310583  -122.33335756
# 2                     NaN       31.0    18081.0  47.61334897  -122.33769944
# 4                     NaN       31.0    19576.0   47.6137544   -122.3409238
# 5                     NaN        7.0    19576.0   47.6164389  -122.33676431
#
#    TotalGHGEmissions  GHGEmissionsIntensity
# 0                NaN                    NaN
# 1                NaN                    NaN
# 2                NaN                    NaN
# 4                NaN                    NaN
# 5                NaN                    NaN

# %% [markdown]
# ### Exportation du dataframe

# %%
#df_tot.to_csv('df_tot.csv', sep = '\t')
